# %%
library(data.table)

# %% [markdown]
# # Data Preparation

# %%
train=fread("CBF/CBF_TRAIN.txt")
test=fread("CBF/CBF_TEST.txt")

# %%
str(train)
# Out:
# Classes 'data.table' and 'data.frame':	30 obs. of  129 variables:
#  $ V1  : num  1 1 1 3 2 2 1 3 2 1 ...
#  $ V2  : num  -0.464 -0.897 -0.465 -0.187 -1.136 ...
#  $ V3  : num  -0.555 -0.686 -0.568 -0.621 -1.319 ...
#  $ V4  : num  -0.843 -1.351 -0.032 -0.816 -1.845 ...
#  $ V5  : num  -0.866 -1.459 -0.635 -0.521 -0.789 ...
#  $ V6  : num  -0.936 -1.165 -0.603 -0.79 -0.252 ...
#  $ V7  : num  -0.817 -1.404 -0.267 -0.968 -1.488 ...
#  $ V8  : num  -0.264 -1.822 -0.267 -1.487 -0.669 ...
#  $ V9  : num  -1.258 -0.832 -0.931 -0.278 -0.34 ...
#  $ V10 : num  -1.25 -1.016 -0.449 -0.835 -1.046 ...
#  $ V11 : num  -0.9183 -0.8035 -0.7213 0.0506 -0.3122 ...
#  $ V12 : num  -0.922 -1.26 -0.397 -0.811 -1.031 ...
#  $ V13 : num  -0.984 -1.139 -0.962 -1.226 -1.201 ...
#  $ V14 : num  -1.288 -0.879 -1.421 -0.668 -0.65 ...
#  $ V15 : num  -1.143 -1.549 -0.783 -0.777 -1.62 ...
#  $ V16 : num  -1.0489 -0.9242 -0.4624 0.0641 -0.4128 ...
#  $ V17 : num  -0.365 -1.395 -1.176 -1.254 -1.051 ...
#  $ V18 : num  -0.691 0.777 -0.502 -0.789 -1.175 ...
#  $ V19 : num  -0.981 1.101 -0.585 -0.934 -0.428 ...
#  $ V20 : num  -0.991 1.19 -0.579 -1.094 -1.2 ...
#  $ V21 : num  -0.887 0.375 -0.921 -0.608 -0.587 ...
#  $ V22 : num  -1.11 0.947 -0.716 -0.703 -1.173 ...
#  $ V23 : num  -0.7687 0.8037 -0.5478 0.0183 -0.3188 ...
#  $ V24 : num  -1.01 1.157 -0.991 2.976 -1.71 ...
#  $ V25 : num  -0.847 0.887 -0.146 2.677 -1.692 ...
#  $ V26 : num  -1.33 1.04 -0.72 2.4 -1.05 ...
#  $ V27 : num  -0.713 0.815 1.159 1.422 -1.332 ...
#  $ V28 : num  -1.298 0.791 0.677 1.977 -0.69 ...
#  $ V29 : num  1.331 0.541 1.429 2.578 -0.745 ...
#  $ V30 : num  0.936 0.858 1.445 1.798 -0.984 ...
#  $ V31 : num  1.236 0.673 1.321 2.081 -1.191 ...
#  $ V32 : num  1.056 0.445 1.436 2.428 -0.549 ...
#  $ V33 : num  0.911 -0.122 1.694 2.056 0.585 ...
#  $ V34 : num  1.371 0.92 1.48 1.897 -0.592 ...
#  $ V35 : num  0.937 0.894 1.403 1.543 -0.763 ...
#  $ V36 : num  0.91 0.806 1.801 1.445 -0.283 ...
#  $ V37 : num  0.931 0.511 1.581 1.812 -0.435 ...
#  $ V38 : num  1.494 1.344 1.538 1.996 0.126 ...
#  $ V39 : num  1.319 0.528 1.33 1.282 -0.329 ...
#  $ V40 : num  1.22 0.88 1.02 1.16 -1.45 ...
#  $ V41 : num  0.948 0.466 1.484 0.638 -0.528 ...
#  $ V42 : num  0.169 1.207 1.533 1.171 -0.091 ...
#  $ V43 : num  0.9774 1.1079 1.0458 1.9631 0.0791 ...
#  $ V44 : num  1.23 0.457 1.424 0.771 -1.144 ...
#  $ V45 : num  0.572 1.178 1.084 1.356 -1.034 ...
#  $ V46 : num  0.751 1 1.521 1.069 -0.456 ...
#  $ V47 : num  0.962 0.476 1.258 0.966 -0.535 ...
#  $ V48 : num  0.7813 0.0549 1.7499 0.6315 -0.1335 ...
#  $ V49 : num  1.104 0.449 1.247 1.324 -0.234 ...
#  $ V50 : num  1.0003 1.3882 1.0419 0.5775 0.0517 ...
#  $ V51 : num  0.551 0.967 0.948 0.619 0.702 ...
#  $ V52 : num  0.269 0.936 1.074 0.71 0.237 ...
#  $ V53 : num  1.126 0.838 0.903 0.717 0.452 ...
#  $ V54 : num  1.0759 0.9106 1.5119 0.0642 -0.7224 ...
#  $ V55 : num  1.072 1.366 1.393 0.786 -1.243 ...
#  $ V56 : num  1.154 1.069 1.3 0.429 0.462 ...
#  $ V57 : num  0.759 0.752 0.838 -0.129 0.532 ...
#  $ V58 : num  0.151 0.572 1.257 0.267 0.361 ...
#  $ V59 : num  1.0203 1.094 1.2914 -0.2229 0.0354 ...
#  $ V60 : num  1.257 0.648 0.933 -0.523 0.315 ...
#  $ V61 : num  1.007 0.53 1.132 -0.156 0.539 ...
#  $ V62 : num  1.162 0.498 1.299 -0.983 0.182 ...
#  $ V63 : num  0.83 0.526 1.087 -0.173 -0.381 ...
#  $ V64 : num  1.4851 1.1162 0.8844 -0.113 -0.0387 ...
#  $ V65 : num  1.1051 0.6611 1.7117 0.0686 0.5843 ...
#  $ V66 : num  1.5393 1.2358 1.8816 0.0621 -0.324 ...
#  $ V67 : num  1.1156 0.3184 2.0142 -0.9874 0.0285 ...
#  $ V68 : num  1.891 0.838 1.358 -0.158 -0.11 ...
#  $ V69 : num  1.3901 0.7405 1.7429 -0.8753 -0.0909 ...
#  $ V70 : num  1.1567 0.0208 -0.1946 -0.6677 0.3444 ...
#  $ V71 : num  1.515 1.073 -0.692 -0.75 0.294 ...
#  $ V72 : num  1.634 0.584 -0.784 -0.644 0.77 ...
#  $ V73 : num  0.81 0.523 -1.046 -0.226 0.462 ...
#  $ V74 : num  0.677 0.768 -0.913 -1.033 0.257 ...
#  $ V75 : num  0.709 0.028 -0.638 -1.097 1.165 ...
#  $ V76 : num  1.3614 0.5349 -0.5134 -0.0796 0.6177 ...
#  $ V77 : num  1.312 1.16 -0.719 -0.697 -0.24 ...
#  $ V78 : num  0.592 0.673 -0.625 -0.129 0.674 ...
#  $ V79 : num  0.832 0.515 -1.095 -0.383 0.21 ...
#  $ V80 : num  1.097 0.731 -0.408 -0.624 0.751 ...
#  $ V81 : num  0.965 0.5571 -0.8497 0.0821 1.0555 ...
#  $ V82 : num  0.9259 0.6739 -0.3461 -0.6017 -0.0199 ...
#  $ V83 : num  1.236 0.738 -0.533 -0.808 0.414 ...
#  $ V84 : num  1.122 0.758 -0.299 -0.687 0.955 ...
#  $ V85 : num  0.935 0.613 -0.954 -0.756 0.303 ...
#  $ V86 : num  1.217 0.844 -1.017 0.254 0.227 ...
#  $ V87 : num  -1.607 0.231 -0.644 0.168 1.27 ...
#  $ V88 : num  -0.595 0.811 -0.183 -0.899 1.024 ...
#  $ V89 : num  -0.757 0.466 -0.594 0.315 0.611 ...
#  $ V90 : num  -0.566 1.059 -0.955 -0.64 0.628 ...
#  $ V91 : num  -0.6485 1.0508 -0.8357 0.0549 0.8048 ...
#  $ V92 : num  -0.6565 0.261 -0.0685 -1.061 1.2576 ...
#  $ V93 : num  -0.532 0.526 -0.997 -0.115 0.278 ...
#  $ V94 : num  -0.115 0.745 -0.575 -0.428 1.012 ...
#  $ V95 : num  -0.573 1.273 -0.879 -0.227 0.948 ...
#  $ V96 : num  -0.541 -1.438 -0.573 -0.541 1.313 ...
#  $ V97 : num  -0.7 -1.05 -1.31 -0.54 1.06 ...
#  $ V98 : num  -1.199 -1.287 -0.764 -0.141 0.868 ...
#  $ V99 : num  -0.953 -1.482 -1.298 -1.053 0.673 ...
#   [list output truncated]
#  - attr(*, ".internal.selfref")=<externalptr>

# %% [markdown]
# # Genlasso

# %%
library("genlasso", quietly = TRUE)

# %%
value_obtainer=function(dataset, index){
    return (as.numeric(dataset[index,2:129]))
}

# %% [markdown]
# # Task 1

# %% [markdown]
# ## Fused Lasso Function

# %%
fused_lasso=function(dataset, index, control=0){
    result = trendfilter(value_obtainer(train, index), ord=0) 
    cv = cv.trendfilter(result)   
    plot(cv)
    print(paste0(index,". Timeseries") )
    print(paste0("Lambda Value of ",index,". dataset for min value: ", cv$lambda.min))
    print(paste0("Lambda Value of ",index,". dataset for 1se value: ", cv$lambda.1se))
    sqrt(seq(1:500000)**2)
    
    plot(result, lambda=cv$lambda.min, main=paste0("Plot of ", index,". Timeseries with lambda min parameter"))  

    if(control==1){
        sqrt(seq(1:500000)**2)
        return(result)
    }    
}

# %%
# fused_plot=function(result, index){
#     cv = cv.trendfilter(result)
# }

# %% [markdown]
# ## Example Result

# %%
fused_lasso(train, 1, 1)
# Out:
# Fold 1 ... Fold 2 ... Fold 3 ... Fold 4 ... Fold 5 ...
# [1] "1. Timeseries"
# [1] "Lambda Value of 1. dataset for min value: 0.5087665975"
# [1] "Lambda Value of 1. dataset for 1se value: 2.74044973866672"
# plot without title
# Call:
# trendfilter(y = value_obtainer(train, index), ord = 0)
#
# Output:
# Path model with 127 total steps.
# Plot with title "Plot of 1. Timeseries with lambda min parameter"

# %% [markdown]
# ### Açıklamalar

# %% [markdown]
# ## Results of Task 1 for All Time Series

# %%
for(i in seq(1:30)){
    fused_lasso(train, i)
}
# Out:
# Fold 1 ... Fold 2 ... Fold 3 ... Fold 4 ... Fold 5 ...
# [1] "1. Timeseries"
# [1] "Lambda Value of 1. dataset for min value: 0.5087665975"
# [1] "Lambda Value of 1. dataset for 1se value: 2.74044973866672"
# plot without title
# Fold 1 ... Fold 2 ... Fold 3 ... Fold 4 ... Fold 5 ...
# Plot with title "Plot of 1. Timeseries with lambda min parameter"
# [1] "2. Timeseries"
# [1] "Lambda Value of 2. dataset for min value: 1.54482427000001"
# [1] "Lambda Value of 2. dataset for 1se value: 3.68318913770684"
# plot without title
# Fold 1 ... Fold 2 ... Fold 3 ... Fold 4 ... Fold 5 ...
# Plot with title "Plot of 2. Timeseries with lambda min parameter"
# [1] "3. Timeseries"
# [1] "Lambda Value of 3. dataset for min value: 0.673140352142856"
# [1] "Lambda Value of 3. dataset for 1se value: 1.76711718240919"
# plot without title
# Fold 1 ... Fold 2 ... Fold 3 ... Fold 4 ... Fold 5 ...
# Plot with title "Plot of 3. Timeseries with lambda min parameter"
# [1] "4. Timeseries"
# [1] "Lambda Value of 4. dataset for min value: 1.21465872541667"
# [1] "Lambda Value of 4. dataset for 1se value: 2.79903382499999"
# plot without title
# Fold 1 ... Fold 2 ... Fold 3 ... Fold 4 ... Fold 5 ...
# Plot with title "Plot of 4. Timeseries with lambda min parameter"
# [1] "5. Timeseries"
# [1] "Lambda Value of 5. dataset for min value: 1.02161963043478"
# [1] "Lambda Value of 5. dataset for 1se value: 3.32583449999999"

# %% [markdown]
# # Task 2

# %% [markdown]
# ## Caret

# %%
library(caret)
library(rpart)

# %% [markdown]
# ### Value Obtainer as DataFrame

# %%
value_obtainer_2=function(dataset, index){
    a=data.table(time=seq(1,128), values=as.numeric(dataset[index,2:129]))
    return (a)
}

# %% [markdown]
# ### Example Code for Regressor

# %%
regression_results=vector("list", 5)

# %%
current_dt=value_obtainer_2(train,1)

# %%
train_control= trainControl(method="cv", number=10)

# %%
for(i in 1:5){
    model = train(values ~., data = current_dt, 
          method = "rpart",
          tuneGrid = data.frame(cp = 0),
          control = rpart.control(minsplit = 20, minbucket = 10, maxdepth=i))
    regression_results[[i]]=model$results 
}

# %%
reg_res=rbindlist(regression_results)
reg_res[,max_depth:=seq(1,5)]
reg_res[,cp:=NULL]

# %%
reg_res

# %%
which.min(reg_res$RMSE)

# %%
model_final = train(values ~., data = current_dt, 
          method = "rpart",
          tuneGrid = data.frame(cp = 0),
          control = rpart.control(minsplit = 20, minbucket = 10, maxdepth=which.min(reg_res$RMSE)))
    regression_results[[i]]=model$results

# %% [markdown]
# ## Example Result

# %%
predictions=predict(model_final,newdata=current_dt)

# %%
plot(predictions,type="l", xlim=c(0,130), ylim=c(-1.7,2), main="Plot of 1. Timeseries with Regressor and maxdepth=3")
points(current_dt[,.(values)])

# %% [markdown]
# ## Regression Function

# %%
regression_function=function(dataset, index){
    regression_results=vector("list", 5)

    current_dt=value_obtainer_2(dataset,index)

    train_control= trainControl(method="cv", number=10)

    for(i in 1:5){
        model = train(values ~., data = current_dt, 
              method = "rpart",
              tuneGrid = data.frame(cp = 0),
              control = rpart.control(minsplit = 20, minbucket = 10, maxdepth=i))
        regression_results[[i]]=model$results 
    }
    
    print(paste0(index,". Timeseries") )
    reg_res=rbindlist(regression_results)
    reg_res[,max_depth:=seq(1,5)]
    reg_res[,cp:=NULL]

    
    best_parameter=which.min(reg_res$RMSE)

    model_final = train(values ~., data = current_dt, 
              method = "rpart",
              tuneGrid = data.frame(cp = 0),
              control = rpart.control(minsplit = 20, minbucket = 10, maxdepth=best_parameter))
        regression_results[[i]]=model$results 

    predictions=predict(model_final,newdata=current_dt)
    
    print(reg_res)
    print(paste0("Best Parameter Value according to RMSE for Max Depth: ", best_parameter))   
    
    sqrt(seq(1:500000)**2)
    
    plot(predictions,type="l", xlim=c(0,130), ylim=c(-1.7,2), main=paste0("Plot of ", index,". Timeseries with Regressor and maxdepth=",best_parameter))
    points(current_dt[,.(values)])
    
}

# %% [markdown]
# ## Results of Task 1 for All Time Series

# %%
for(i in seq(1:30)){
    regression_function(train, i)

}

# %% [markdown]
# # Task 3

# %% [markdown]
# # Task 4

# %%
example=fusedlasso1d(as.numeric(train[1,2:129]))

# %%
plot(example, style="path")

# %%
example$lambda
