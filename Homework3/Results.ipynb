# %%
acc_res_1=dataframe_result_1[,list(avg_acc=mean(acc),sdev_acc=sd(acc), repid=max(repid), foldid=max(foldid), 
                                   result_count=.N),by=list(approach,k)]
acc_res_1[order(avg_acc)]
# Out:
#    approach                        k  avg_acc    sdev_acc  repid foldid
# 1  Beef_lcss_paa_epsilon_005.csv    5 0.03333333 0.1010153 5     10
# 2  Beef_lcss_paa_epsilon_005.csv   10 0.03333333 0.1010153 5     10
# 3  Beef_lcss_paa2_epsilon_005.csv   5 0.03333333 0.1010153 5     10
# 4  Beef_lcss_paa2_epsilon_005.csv  10 0.03333333 0.1010153 5     10
# 5  Beef_lcss_raw_epsilon_005.csv    1 0.03333333 0.1010153 5     10
# 6  Beef_lcss_raw_epsilon_005.csv    5 0.03333333 0.1010153 5     10
# 7  Beef_lcss_raw_epsilon_005.csv   10 0.03333333 0.1010153 5     10
# 8  Beef_dtw_diff2_dist.csv         10 0.04000000 0.1094202 5     10
# 9  Beef_dtw_diff_dist.csv          10 0.06000000 0.1458418 5     10
# 10 Beef_euc_diff2_dist.csv         10 0.06000000 0.1458418 5     10
# 11 Beef_euc_diff_dist.csv          10 0.06666667 0.1649572 5     10
# 12 Beef_lcss_paa_epsilon_005.csv    1 0.07333333 0.1394840 5     10
# 13 Beef_lcss_paa2_epsilon_005.csv   1 0.07333333 0.1394840 5     10
# ...
