# %%
library(data.table)

# %%
x_train=fread("UWave-20211030T180805Z-001/UWave/uWaveGestureLibrary_X_TRAIN")
y_train=fread("UWave-20211030T180805Z-001/UWave/uWaveGestureLibrary_Y_TRAIN")
z_train=fread("UWave-20211030T180805Z-001/UWave/uWaveGestureLibrary_Z_TRAIN")

# %%
head(x_train)
# Out:
#   V1 V2           V3           V4           V5           V6
# 1 6  -0.304243210 -0.304243210 -0.304243210 -0.304243210 -0.304243210
# 2 5   1.627311100  1.627311100  1.627311100  1.627311100  1.627311100
# 3 5   0.661276530  0.661276530  0.661276530  0.661276530  0.661276530
# 4 3   0.005184784  0.005184784  0.005184784  0.005184784  0.005184784
# 5 4   1.286197800  1.286197800  1.286197800  1.286197800  1.286197800
# 6 8  -0.479252460 -0.479252460 -0.479252460 -0.479252460 -0.479252460
#   V7           V8           V9           V10          ... V307       V308
# 1 -0.304243210 -0.304243210 -0.304243210 -0.304243210 ... -0.7964140 -0.7417282
# 2  1.627311100  1.627311100  1.627311100  1.627311100 ... -0.2376337 -0.2376337
# 3  0.661276530  0.661276530  0.661276530  0.661276530 ... -0.2820107 -0.2369291
# 4  0.005184784  0.005184784  0.005184784  0.005184784 ...  1.2072899  1.1478218
# 5  1.286197800  1.286197800  1.286197800  1.286197800 ... -1.4369826 -1.4369826
# 6 -0.479252460 -0.479252460 -0.479252460 -0.479252460 ...  0.5784697  0.5877041
#   V309       V310       V311       V312        V313        V314
# 1 -0.6946985 -0.6476688 -0.6476688 -0.64766875 -0.64766875 -0.64766875
# 2 -0.2376337 -0.2376337 -0.2376337 -0.23763371 -0.23763371 -0.23763371
# 3 -0.1918477 -0.1467662 -0.1016848 -0.06120346 -0.05663826 -0.05546207
# 4  1.0943436  1.0603618  1.0531583  1.04446710  1.01898080  0.90994938
# 5 -1.4369826 -1.4369826 -1.4369826 -1.44034250 -1.45251250 -1.46844580
# 6  0.5969386  0.6061730  0.6207059  0.63523879  0.65370767  0.67217655
#   V315        V316
# 1 -0.64766875 -0.64766875
# 2 -0.23763371 -0.23763371
# 3 -0.05546207 -0.05546207
# 4  0.79101316  0.67207694
# 5 -1.48437920 -1.50031250
# 6  0.69064543  0.70911432

# %%
write.csv(x_train, "uWaveGestureLibrary_X_TRAIN.csv", row.names = FALSE)

# %%
write.csv(y_train, "uWaveGestureLibrary_Y_TRAIN.csv", row.names = FALSE)

# %%
write.csv(z_train, "uWaveGestureLibrary_Z_TRAIN.csv", row.names = FALSE)
