# %%
import numpy as np
import pandas as pd
import datatable as dt
import matplotlib.pyplot as plt
import os

# %%
from matplotlib import pyplot
from mpl_toolkits.mplot3d import Axes3D
import random

# %%
os.getcwd()
# Out:
# 'C:\\Users\\bahad\\GitHub\\IE48B\\Homework1'

# %%
Folder_path="UWave-20211030T180805Z-001/UWave/"

# %%
x_train, y_train, z_train =pd.read_csv(f"{Folder_path}uWaveGestureLibrary_X_TRAIN.csv"),\
                           pd.read_csv(f"{Folder_path}uWaveGestureLibrary_Y_TRAIN.csv"),\
                           pd.read_csv(f"{Folder_path}uWaveGestureLibrary_Z_TRAIN.csv")

# %%
class_indicator=pd.DataFrame(x_train.iloc[:, 0])

# %%
acc_x=x_train.iloc[:,1:].T.cumsum().T.add_suffix("_X")
acc_y=y_train.iloc[:,1:].T.cumsum().T.add_suffix("_Y")
acc_z=z_train.iloc[:,1:].T.cumsum().T.add_suffix("_Z")

# %%
dataframes=[class_indicator, acc_x, acc_y, acc_z]

# %%
all_acc=pd.concat(dataframes, axis=1)

# %% [markdown]
# ## Gesture Filter

# %%
def filter_data(ind_data, x_data, y_data, z_data, index):

    x_concat=pd.concat([ind_data,x_data], axis=1)
    x_filtered=x_concat[x_concat.iloc[:, 0]== index].iloc[:, 1:]
    
    y_concat=pd.concat([ind_data,y_data], axis=1)
    y_filtered=y_concat[y_concat.iloc[:, 0]== index].iloc[:, 1:]
    
    z_concat=pd.concat([ind_data,z_data], axis=1)
    z_filtered=z_concat[z_concat.iloc[:, 0]== index].iloc[:, 1:]
    
    return x_filtered, y_filtered, z_filtered

# %% [markdown]
# # Display

# %%
import plotly.express as px

# %% [markdown]
# ## Gesture 1

# %%
x_1, y_1, z_1 = filter_data(class_indicator, acc_x, acc_y, acc_z, 1)

# %%
fig = pyplot.figure()
fig.set_size_inches(18.5, 10.5)
ax = Axes3D(fig)

ax.scatter(x_1.T.cumsum().iloc[:, 0], y_1.T.cumsum().iloc[:, 0], z_1.T.cumsum().iloc[:, 0],)
ax.set_title("Geture 1 Example")
ax.set_xlabel("X axis")
ax.set_ylabel("Y axis")
ax.set_zlabel("Z axis")
pyplot.show()

# %% [markdown]
# ## Plotly Plot

# %%
fig1=px.scatter_3d(x=x_1.T.cumsum().iloc[:, 0], y=y_1.T.cumsum().iloc[:, 0], z=z_1.T.cumsum().iloc[:, 0],
             labels=dict(x="X Axis", y="Y Axis", z="Z Axis"), title="Gesture 1 Example")
fig1.update_traces(marker=dict(size=4,opacity=0.4))
# Out:
# <div>                            <div id="b6eec301-483e-42bc-a9b9-78f1adde0f8d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b6eec301-483e-42bc-a9b9-78f1adde0f8d")) {                    Plotly.newPlot(                        "b6eec301-483e-42bc-a9b9-78f1adde0f8d",                        [{"hovertemplate":"X Axis=%{x}<br>Y Axis=%{y}<br>Z Axis=%{z}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","opacity":0.4,"size":4,"symbol":"circle"},"mode":"markers","name":"","scene":"scene","showlegend":false,"type":"scatter3d","x":[-0.79144718,-2.37434154,-4.75310863,-7.94194073,-11.98000285,-16.92152975,-22.794202910000003,-29.617479480000004,-37.391359460000004,-46.11584285000001,-55.79092965000001,-66.41661986000001,-77.99291348000001,-90.51981051000001,-103.99731095000001,-118.42541480000001,-133.80412206,-150.13343272999998,-167.41334680999998,-185.64386429999996,-204.82498519999996,-224.95670950999994,-246.03903722999993,-268.0719683599999,-291.0555028999999,-314.9896408499999,-339.8743822099999,-365.7097269799999,-392.4956751599999,-420.2372627299999,-448.95121633999986,-478.66063119999984,-509.3926247599998,-541.1522848199999,-573.9421265799998,-607.7621500399998,-642.6123551999998,-678.4927420599998,-715.3939363199999,-753.3022497799999,-792.1905650099999,-832.0143512199999,-872.7105034099999,-914.2013972799999,-956.4110762999999,-999.3083681499999,-1042.86592654,-1087.06170275,-1131.88976971,-1177.35012742,-1223.44277588,-1270.16771509,-1317.52494505,-1365.5273063900001,-1414.1940600500002,-1463.5521544500002,-1513.6440111100003,-1564.5494616500002,-1616.3416230600003,-1669.0891758900002,-1722.8228129100003,-1777.5696515300003,-1833.3568092500004,-1890.2114034700005,-1948.1605514900004,-2007.2139329100005,-2067.3771559300003,-2128.6507274500004,-2191.0477442700003,-2254.5953237900003,-2319.3026796100003,-2385.1684546300003,-2452.1384140500004,-2520.16432917,-2589.2066642900004,-2659.2348301700004,-2730.2210062900003,-2802.1162799700005,-2874.8692968500004,-2948.4240481300003,-3022.70790186,-3097.6395057500004,-3173.1375075200003,-3249.1205549100005,-3325.5072957000007,-3402.216377670001,-3479.1664486100008,-3556.276156300001,-3633.459188839001,-3710.6111315000007,-3787.627035431001,-3864.401472172001,-3940.849206243001,-4016.885833314001,-4092.409726465001,-4167.303556776001,-4241.431737187001,-4314.645338598001,-4386.790690209001,-4457.705087620001,-4527.235505931001,-4595.2435703420015,-4661.595941953002,-4726.161832464002,-4788.832771975002,-4849.504092086002,-4908.078727697002,-4964.469751308002,-5018.595811119002,-5070.410964730002,-5119.875493741002,-5166.962280452002,-5211.644207563002,-5253.894157974002,-5293.6949665850025,-5331.039469296003,-5365.954783107002,-5398.4680251180025,-5428.606312629003,-5456.396763240003,-5481.8692579510025,-5505.070682062003,-5526.051239973002,-5544.865166484003,-5561.566696295003,-5576.210579206003,-5588.857892817003,-5599.577562928002,-5608.450941739003,-5615.549639250003,-5620.940927161003,-5624.679040272003,-5626.818213483002,-5627.412681594003,-5626.516679405003,-5624.184441816003,-5620.470203627003,-5615.426106838003,-5609.098276349003,-5601.522004860003,-5592.724409771003,-5582.719200982003,-5571.515984393003,-5559.114760004003,-5545.526798815003,-5530.774403026003,-5514.881945837003,-5497.871059048002,-5479.741742659002,-5460.498130570002,-5440.149599881002,-5418.718880592002,-5396.233090003002,-5372.719345614002,-5348.204764825002,-5322.716465086002,-5296.281563807002,-5268.927178388002,-5240.680426219003,-5211.568424710003,-5181.618291321002,-5150.857143482002,-5119.3120986130025,-5087.010274104003,-5053.983174755002,-5020.2756583260025,-4985.937825677002,-4951.0239116480025,-4915.523255649003,-4879.416972750003,-4842.692391231003, ...

# %% [markdown]
# ## Gesture 2

# %%
x_2, y_2, z_2 = filter_data(class_indicator, acc_x, acc_y, acc_z, 2)

# %% [markdown]
# ## Gesture 3

# %%
x_3, y_3, z_3 = filter_data(class_indicator, acc_x, acc_y, acc_z, 3)
